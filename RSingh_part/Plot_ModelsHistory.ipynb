# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file
file_path = './Project4_CSVFiles/JackyZ/h1_df.csv'  # Update this to your actual file path if needed
df = pd.read_csv(file_path)

# Plotting the graphs

# 1. Line Plot of Accuracy over Epochs
plt.figure(figsize=(12, 6))
plt.plot(df1.index, df1['accuracy'], label='Train Accuracy', color='blue')
plt.plot(df1.index, df1['val_accuracy'], label='Val Accuracy', color='orange')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Accuracy Over Epochs')
plt.legend()
plt.grid(True)
plt.show()

# 2. Line Plot of Loss over Epochs
plt.figure(figsize=(12, 6))
plt.plot(df.index, df['loss'], label='Training Loss', color='blue')
plt.plot(df.index, df['val_loss'], label='Validation Loss', color='orange')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss Over Epochs')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# #### Optimisation Method 1: Adding more epochs and adjust the data augumentation:
# ##### set the new epochs to 40
# ###### Apply more angle on rotating and zooming

# %%
# h2_df.to_csv('/content/drive/MyDrive/Colab_Notebooks/Brain_Tumor_MRI/opt1_df.csv', index=False, header = True)


# Load the CSV file
file_path = './Project4_CSVFiles/JackyZ/opt1_df.csv'  # Update this to your actual file path if needed
df1 = pd.read_csv(file_path)


# 1. Line Plot of Accuracy over Epochs
plt.figure(figsize=(12, 6))
plt.plot(df1.index, df1['accuracy'], label='Train Accuracy', color='blue')
plt.plot(df1.index, df1['val_accuracy'], label='Val Accuracy', color='orange')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Accuracy Over Epochs')
plt.legend()
plt.grid(True)
plt.show()

# 1. Line Plot of Loss over Epochs
plt.figure(figsize=(12, 6))
plt.plot(df1.index, df1['loss'], label='Training Loss', color='blue')
plt.plot(df1.index, df1['val_loss'], label='Validation Loss', color='orange')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss Over Epochs')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Load the CSV file
file_path = './Project4_CSVFiles/JackyZ/training_log_loadedModel2_valAccuracy.csv'  # Update this to your actual file path if needed
df2 = pd.read_csv(file_path)


# 1. Line Plot of Accuracy over Epochs
plt.figure(figsize=(12, 6))
plt.plot(df2.index, df2['accuracy'], label='Train Accuracy', color='blue')
plt.plot(df2.index, df2['val_accuracy'], label='Val Accuracy', color='orange')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Accuracy Over Epochs')
plt.legend()
plt.grid(True)
plt.show()

# 1. Line Plot of Loss over Epochs
plt.figure(figsize=(12, 6))
plt.plot(df2.index, df2['loss'], label='Training Loss', color='blue')
plt.plot(df2.index, df2['val_loss'], label='Validation Loss', color='orange')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss Over Epochs')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Load the CSV file
file_path = './Project4_CSVFiles/JackyZ/training_log_loadedModel2_valLoss.csv'  # Update this to your actual file path if needed
df3 = pd.read_csv(file_path)


# 1. Line Plot of Accuracy over Epochs
plt.figure(figsize=(12, 6))
plt.plot(df3.index, df3['accuracy'], label='Train Accuracy', color='blue')
plt.plot(df3.index, df3['val_accuracy'], label='Val Accuracy', color='orange')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Accuracy Over Epochs')
plt.legend()
plt.grid(True)
plt.show()

# 1. Line Plot of Loss over Epochs
plt.figure(figsize=(12, 6))
plt.plot(df3.index, df3['loss'], label='Training Loss', color='blue')
plt.plot(df3.index, df3['val_loss'], label='Validation Loss', color='orange')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss Over Epochs')
plt.legend()
plt.grid(True)
plt.show()
